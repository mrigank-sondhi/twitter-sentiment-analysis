# %%
#This file performs the following functions:
#1. Extracts streaming data from Twitter using Tweepy with Twitter API v2
#2. Pre-processes the data
#3. Loads it into a MySQL database

import credentials #Import the keys from credentials.py
import settings #Import the related setting constants from settings.py 

import re
import tweepy
import mysql.connector
import pandas as pd
from textblob import TextBlob
from dateutil import parser #for converting ISO 8601 date into the correct format
import json #to convert the decoded raw tweet data string to a dictionary

# %%
#Override the tweepy.StreamingClient class to add logic to on_data
class MyStream(tweepy.StreamingClient):
    #This is called when raw data is received from the stream. This method handles sending the 
    #data to other methods.
    def on_data(self, raw_data):
        '''
        Extract info from tweets
        ''' 
        #decoding the raw data which is in the form of a byte object we get a string of a dict,
        #we then convert the string to an actual dict and store it in data
        data = json.loads(raw_data.decode('utf-8'))
        #Extract the attributes from each tweet
        tweet_id = data['data']['id'] #Tweet ID
        created_at = parser.parse(data['data']['created_at']).strftime("%Y-%m-%d %H:%M:%S") #Creation time of the Tweet
        text = remove_emojis(data['data']['text']) #Content of the tweet, pre-processing it  
        retweet_count = data['data']['public_metrics']['retweet_count']
        like_count = data['data']['public_metrics']['like_count']
        longitude = None
        latitude = None
        if 'coordinates' in data['data']['geo']:
            longitude = data['data']['geo']['coordinates']['coordinates'][0]
            latitude = data['data']['geo']['coordinates']['coordinates'][1]
        sentiment = TextBlob(text).sentiment #Retrieving the sentiment of the tweet
        polarity = sentiment.polarity #Retrieving the polarity of the tweet
        subjectivity = sentiment.subjectivity #Retrieving the sentiment of the tweet
        
        #Extracting user info
        user_created_at = parser.parse(data['includes']['users'][0]['created_at']).strftime("%Y-%m-%d %H:%M:%S")
        user_location = None
        if 'location' in data['includes']['users'][0]:
            user_location = remove_emojis(data['includes']['users'][0]['location'])
        user_description = remove_emojis(data['includes']['users'][0]['description'])
        user_followers_count = data['includes']['users'][0]['public_metrics']['followers_count']
        
        print(data['data']['text'])
        print(f'Longitude: {longitude}, Latitude: {latitude}')
        
        #Storing all the data in MySQL database
        if database.is_connected():
            cursor = database.cursor()
            query = f"INSERT INTO {settings.TABLE_NAME} (tweet_id, created_at, text, polarity, subjectivity, user_created_at, user_location, user_description, user_followers_count, longitude, latitude, retweet_count, like_count) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
            values = (tweet_id, created_at, text, polarity, subjectivity, user_created_at, user_location,
                     user_description, user_followers_count, longitude, latitude, retweet_count,
                     like_count)
            cursor.execute(query, values)
            database.commit()
            cursor.close()
    
#     #This is called when includes are received.
#     def on_includes(self, includes):
#         pass
        
#      #This is called when a Tweet is received.
#     def on_tweet(self, tweet):
#         pass
        
    def on_errors(self, status_code):
        '''
        Since the Twitter API has rate limits, we must stop scraping data once the limit 
        has been crossed.
        '''
        if status_code == 420: #marks the end of the monthly limit rate (2M)
            #return False to disconnect the stream
            return False

# %%
#Functions used to pre-process the tweet text
def clean_tweet_text(self, tweet_text): 
    ''' 
    Removing links and special characters using Regex
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet_text).split()) 
def remove_emojis(tweet_text):
    '''
    Strip all non-ASCII characters so that emojis are removed
    '''
    if tweet_text:
        return tweet_text.encode('ascii', 'ignore').decode('ascii')
    else:
        return None

# %%
#Creating the database
database = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd=credentials.DATABASE_PASSWORD,
    database="twitterdatabase",
    charset = 'utf8'
)
if database.is_connected():
    '''
    Check if the table exits. If it does not, then create a new one.
    '''
    cursor = database.cursor()
    cursor.execute("""
        SELECT COUNT(*)
        FROM information_schema.tables
        WHERE table_name = '{0}'
        """.format(settings.TABLE_NAME))
    if cursor.fetchone()[0] != 1:
        cursor.execute(f"CREATE TABLE {settings.TABLE_NAME} ({settings.TABLE_ATTRIBUTES})")
        database.commit()
    cursor.close()

# %%
#Authentication
client = tweepy.Client(credentials.BEARER_TOKEN)

# %%
#Streaming tweets
myStream = MyStream(credentials.BEARER_TOKEN)
#For filtering twitter tweets we need to set up rules so that tweets are streamed accordingly 
#Deleting any previous rules if they exist
if myStream.get_rules()[0]:
    myStream.delete_rules([rule.id for rule in myStream.get_rules()[0]])
#Adding a new rule
myStream.add_rules(tweepy.StreamRule(f"{settings.TRACK_WORDS} lang:en -is:retweet"))
#Filtering the tweets using the rule added and using expansions to gather non-default tweet data
myStream.filter(expansions=['author_id'], 
                user_fields=['created_at','location','description','public_metrics'],
                tweet_fields=['created_at','geo','public_metrics'])
#The following part won't be reached as the streaming client won't stop automatically 
#We need to STOP it manually
#Closing the database
database.close()
# Out:
# Total Pay$40,300.00
#
# To apply, simply click the link below:
# https://t.co/UVyO9aU2P0
#
# If interested, please contact me via my Facebook account:
# https://t.co/3B3Np4HbdP
# #travelnurselife #travelnurseadventures #travelnurses #travelnursejobs #TravelNurseRepeat
# Longitude: None, Latitude: None
# @amandacarpenter Once again Facebook carries water for the Republican Party. Might as well put a Trump sticker on the Facebook logo. But it will be impossible to stop distribution of abortion pills. States have no authority to open US mail.
# Longitude: None, Latitude: None
# Both of these glass-walled rooms provide a great view of nature while you lounge or dine. Which would you prefer, the log cabin style room, or the more classic choice?
#
# For all your real estate needs.
# https://t.co/thAjK9BrVw
# (631)... https://t.co/JlpzdGtsVU https://t.co/Hoh2Jge6IV
# Longitude: None, Latitude: None
# @TajinderBagga @ashokgehlot51 This is disgrace to humanity.
# Longitude: None, Latitude: None
# Good Tuesday morning, folks.  If you need any library help today, you can reach me at 337-392-3126, e-mail ritterh@nsula.edu, Facebook comment on here, or come by for a visit. However, you wish to receive library assistance, I am here to help.
# Longitude: None, Latitude: None
# No muslim in the quotes ! Imagine my shock https://t.co/POQrWXT8Kt
# Longitude: None, Latitude: None
# And so it begins:
# "Yet, when the AP reporter made the same exact post but swapped out the words 'abortion pills' for 'a gun,' the post remained untouched. A post with the same exact offer to mail 'weed' was also left up and not considered a violation."
#
# https://t.co/umTkSwNl2A
# Longitude: None, Latitude: None
# @TajinderBagga @ashokgehlot51 BOHOT HO GAYA YE SAB !! I REUEST BAJRANG DAL TO CARRY OUT MASS PROTEST AGAINST THIS ACROSS THE COUNTRY AND ERADICATE ALL PEACEFULS IN THEIR WAY
# Longitude: None, Latitude: None
# Please RT Sur 2 jihadi are kill Hindu taller Facebook post supporting Nupur Sharma
#
# #HindusUnderAttackInIndia
# #HinduHatred
# #hindulivesmatters
# 👇👇
# https://t.co/hhRTrcgf7m https://t.co/VO1bZPyJ7v
# Longitude: None, Latitude: None
# BRAKE CENTER
#
# Read here:
# @sneakerheadcoff 💥 FREE MINT! 💥  @WendeEngida @tiavr4 @ChinaFealil @Tranquo11689137 @ashakeel32 @lofton_paula @za_facebook @arnohg @stuartgoodwin17 @Daddy_Uzimaki @itsLyanar @DhiluAntony @ErmannoZardini @tevcimen @RohanSankrit @itstashatae @LeonardoVD20
# Longitude: None, Latitude: None
# Marley #Vermist sinds 12-06-2022 te #Zwolle #Overijssel #Nederland
#
# https://t.co/lUK1UuLX6n https://t.co/fPSvxFSadX
# Longitude: None, Latitude: None
# Excited for this on Thursday 😍 https://t.co/u7eHjmoTNl
# Longitude: None, Latitude: None
# @TajinderBagga @ashokgehlot51 @MahuaMoitra @zoo_bear has caused this. Please justify this barbaric act also. For once please keep aside politics and think of innocent lives. Hindus are human too, we don’t need appeasement but we need justice atleast.
# Longitude: None, Latitude: None
# Mohammad killed Hindu tailor in Udaipur for Supporting Nupur Sharma on his Facebook Status. Mohammad said he wants to Kill PM Modi.
# @narendramodi @AmitShah
# @ https://t.co/KAkpPrV1ob
# Longitude: None, Latitude: None
# This showed up on my Facebook feed this morning. 1/ https://t.co/OehGPyMeHU
# Longitude: None, Latitude: None
# @HMOIndia @PMOIndia
# Why Hindus are feeling unsafe in given situation https://t.co/fYhaasMIjm
# Longitude: None, Latitude: None
# Pain::Two three Muslim youths slaughtered one innocent Hindu man.. 😓😓
# Reason::his eight year son put Nupur Sharma pik on his Facebook status for that his father beheaded..
# Mohammad said he want to Kill Modi also.
# #Udaipur https://t.co/a2zz6Bpg3A
# Longitude: None, Latitude: None
# @MetaNewsroom @FacebookWatch @facebook what gives? https://t.co/4JvC4SUIsR
# Longitude: None, Latitude: None
# Pull me closer
#
# DONBELLE CLOSER MV
#
# #DonBelle
# #closeupxDonBelle
# #CloserWithDonBelle https://t.co/CrDyfj6shw
# Longitude: None, Latitude: None
# @footballiance It’s just gaslighting to suggest one cannot receive a D&amp;C for a non viable pregnancy. Conservatives have long supported exceptions for rape incest or danger to mothers life. This is all deflections to avoid talking about 99% of abortions
# Longitude: None, Latitude: None
# @ArtAficionado2 @SBS0311 @AP They aren't scams...there are actually telehealth services that ship abortion pills.
# Longitude: None, Latitude: None
# Thanks 4 following me. See me on FB https://t.co/PsI7z00XPm #harry_botter
# Longitude: None, Latitude: None
# @flexghost1 THIS! Provoke and incite. Their members should be testifying @ #January6thHearings
# Longitude: None, Latitude: None
# @Ras_miah1998 Sorry about that junior, I had the same issue with my Facebook in 2019 but I had @SapphireTechV3 help me out, he could recover your IG profile
# Longitude: None, Latitude: None
# @TajinderBagga @ashokgehlot51 Yh th allah k bande hai
# Longitude: None, Latitude: None
# WTF?
# Facebook and Instagram are blocking posts about mailing abortion pills https://t.co/THOFf7h2VW via @Yahoo
# Longitude: None, Latitude: None
# @TajinderBagga @ashokgehlot51 This incident is on the man who keeps blabbers 'Sabka-bhikaas,sabka bhisbaas'.
#
# You can't live with animals and expect then to not hurt you.
#
# But then...
# Longitude: None, Latitude: None
# @ActivePatriotUK More criminals and fraudulent individuals bleeding our benefits!
# Longitude: None, Latitude: None
# @TajinderBagga @ashokgehlot51 Warning:
# Graphic content.
#
# Cc: @UN @UNHumanRights
# @geertwilderspvv @RT_Com
# @FoxNews @FRANCE24
# @ABC @abcnews @CNN
#
# #IsupportNupurSharma
# #HindusUnderAttackInIndia
# Longitude: None, Latitude: None
# Quest Photographers photoshoots. Book a photoshoot with us,0728449856. Follow us on Facebook as Quest Photographers and Quest images on Instagram. https://t.co/s2RJLQlFJ2
# Longitude: None, Latitude: None
# Stream Now!! Just Click the link
#
# DONBELLE CLOSER MV
#
# #closeupxDonBelle
# #CloserWithDonBelle https://t.co
# Longitude: None, Latitude: None
# @shell895 Twitter is the place to be https://t.co/kDxH0ZA4AR
# Longitude: None, Latitude: None
# @lesiavasylenko There are still tens of thousands burried under the fronts of Finland and Germany. Russians don't care about their people. Never have, never will.
#
# These guys have been digging up soldiers for a decade. https://t.co/xEGL4bM6J3
# Longitude: None, Latitude: None
# CLOSER MV by Belle Mariano is now available on FB and YT
#
# Facebook:
# 🖇️: https://t.co/KF1sLAwkek
# 🖇️: https://t.co/S1OvmYj6i6
#
# YouTube:
# 🖇️: https://t.co/O5FbrSAL8B
# 🖇️: https://t.co/BInt8qTVXQ
# 🖇️: https://t.co/896T7z9Be7
#
# DONBELLE CLOSER MV
#
# #closeupxDonBelle
# #CloserWithDonBelle
# Longitude: None, Latitude: None
# Waiting for @SECPakistan usual response: it is backed by SeedCred which is licensed and regulated by SECP..yada yada yada https://t.co/pvmZ8MzYP8
# Longitude: None, Latitude: None
# Everytime I see a Facebook memory from 2010-2013, I cringe so hard man
# Longitude: None, Latitude: None
# @SavvyRinu That was what every Nigerian said in 2015 about Buhari- look at where we are today.Imagine Peter Obi becoming president and banning Twitter, Instagram and Facebook within 5 months of his presidency basing it on the fact that too many fake news abound there;from frying pan to fire
# Longitude: None, Latitude: None
# @TajinderBagga @ashokgehlot51 Khangress rule
# Longitude: None, Latitude: None
# @MaryL1973 I don’t have tik Tok. I do have Facebook and Instagram along with Twitter
# Longitude: None, Latitude: None
# @LiamBeh37199636 Enjoy 👍 🙂
# Longitude: None, Latitude: None
# DONBELLE CLOSER MV
#
# #DonBelle
# #closeupxDonBelle
# #CloserWithDonBelle https://t.co/EDGgTa1jWg
# Longitude: None, Latitude: None
# @TajinderBagga @ashokgehlot51 They are openly claiming killing and threatening to kill @narendramodi . Hadd hi jo gaye @ashokgehlot51 . This is democracy ? No
# Longitude: None, Latitude: None
# #cheapest_smm_panel
#
# https://t.co/abCzMqMses is a corporate and trusted website that provides services to improve your account on Social Media platforms like Instagram, Twitter, Facebook, TikTok, YouTube and provides professional SEO services to websites.
# https://t.co/JbZeixXaEy
# Longitude: None, Latitude: None
# DONBELLE CLOSER MV
#
# #closeupxDonBelle
# #CloserWithDonBelle https://t.co/6HRiAO1wnJ
# Longitude: None, Latitude: None
# DONBELLE CLOSER MV
#
# #DonBelle
# #closeupxDonBelle
# #CloserWithDonBelle https://t.co/WmETMTzN2I
# Longitude: None, Latitude: None
# Terorisam on muslims india by terorist moodi PM since 10 years and HR uno must take action  on india   Inorder to avoid  war  and request world shd not keep quiet https://t.co/YLsimtloRt
# Longitude: None, Latitude: None
# DONBELLE CLOSER MV
#
# #DonBelle
# #closeupxDonBelle
# #CloserWithDonBelle https://t.co/CFXXLO0KDD
# Longitude: None, Latitude: None
# Congratulations my loves @donnypangilinan @bellemariano02 👏🖤❤️
#
# DONBELLE CLOSER MV
#
# #closeupxDonBelle
# #CloserWithDonBelle https://t.co/5zbg7R8Df7
# Longitude: None, Latitude: None
# FALL 2022 CITIZEN'S ACADEMY
# https://t.co/cB51gzC3kK https://t.co/LDVpzLOzoI
# Longitude: None, Latitude: None
# @TajinderBagga @ashokgehlot51 @ShashiTharoor You were quick in defending @zoo_bear . Now will you be as quick as condemning what these pigs did to Kishen lal.
# Longitude: None, Latitude: None
# Some photos from last nights @MeathGAA Premier 7 FC v @CurrahaGFC
#
# More on Facebook https://t.co/Aqba9EhEoe
# Longitude: None, Latitude: None
# @TajinderBagga @ashokgehlot51 @khanumarfa @RanaAyyub @svaradarajan In case you have missed to report this incident .
# Longitude: None, Latitude: None
# @adeyanjudeji Future Sowore.
# Longitude: None, Latitude: None
# 🎀 Competition on Facebook 🎀 ---&gt; https://t.co/2sRrtGOEi5
#
# We're giving away bonuses for the game:) Take part in the mini-game at the link and 🎉 win 🎁Gold Gift🎁 and 200 💎
# Longitude: None, Latitude: None
# @DonBelleOFC DONBELLE CLOSER MV
#
# #DonBelle
# #closeupxDonBelle
# #CloserWithDonBelle
# Longitude: None, Latitude: None
# This people should be hanged at the earliest such mindset cannot be &amp; should not be tolerated in India.
#
# Sending them to prison or life sentence would only give motivate more of such #Islamic terrorists in India
#
# #Rajasthan #India #Hindus #Islam #Congress https://t.co/Nd8h8JAQUn https://t.co/32OUb7c3Sf
# Longitude: None, Latitude: None
# This is on you hate mongers .. @zoo_bear you dog-whistled these inhumans https://t.co/WVkLUIRgEw
# Longitude: None, Latitude: None
# @stephyberry_ Pretty 🥰
# Longitude: None, Latitude: None
# Mohammad killed tailor in Udaipur,Rajasthan for Supporting Nupur Sharma on his Facebook Status.
#
# Hindus are unsafe in India
#
# @BJP4Rajasthan @PoliceRajasthan @ndtv @IndiaToday @hrw @UNHumanRights @RajPoliceHelp @HMOIndia @PMOIndia @VHPDigital @BajrangPunia
#
# #NupurSharama https://t.co/9tYz8DJfmu
# Longitude: None, Latitude: None
# A goo ##blockchain #btc #ETH #推特涨粉 #电报加粉 #电报群拉人 #小眼睛浏览 #买粉 #点赞 #白名单 #直播号 #tiktok账号 #投票 #Facebook专页加粉 #专页赞 #专页粉 #点赞 #评论 #分享 #直播间人气 d example is the best sermon
# Longitude: None, Latitude: None
# SNEAKERS - 👟
#
# SIZE : 40 - 46
#
# TO PLACE ORDER :  DM OR CLICK LINK IN BIO
#
# WHATSAPP OR 📲 📞 :  08139007938
#
# TWITTER :  @MadeMenClothinz
#
# FACEBOOK :  MadeMen Clothingz
#
# WORLDWIDE 🌍 DELIVERY 📦 🚚
#
# #mademen_clothingz https://t.co/pgiunG8Id2
# Longitude: None, Latitude: None
# I don’t know who asked me to mistakenly stroll into Facebook this afternoon 😭😭😭 https://t.co/u490fc4cZl
# Longitude: None, Latitude: None
# DONBELLE CLOSER MV
#
# #DonBelle
# #closeupxDonBelle
# #CloserWithDonBelle https://t.co/ndbcFGz7c3
# Longitude: None, Latitude: None
# Theosophy https://t.co/UjhwY1n6AU
# Longitude: None, Latitude: None
# @WSJ All board members of Trump’s Digital Media SPAC have been subpoenaed by the SEC. This SPAC is down 52%.  Merger is doubtful.
# Longitude: None, Latitude: None
# @TajinderBagga @ashokgehlot51 Very cruel just like Shambhu Ragger did that.
#
# It's Big criminal offense.
# No need to evidence or date, court must take it seriously and sentence him for hang. Immediately.
#
# 😡😡😡
# Longitude: None, Latitude: None
# @SwagPanther69 @wtf1official you're not getting my point, i'm trying to tell you that sim racing is not just a controller in front of a tv, but an actual way to practice your racecraft. no, it's never gonna be the same as real racing, but it does have traits from it. go back to facebook bro
# Longitude: None, Latitude: None
# @TajinderBagga @ashokgehlot51 Rajasthan badly needs a yogi....
# Longitude: None, Latitude: None
# https://t.co/wxqoMwPDXy Hey didn't I told you that more rewards are coming to that policeman that found and return the lost money? Here👇 it's one business mogul paid for him the pilgrimage fare to Saudi Arabia. This is also the tip of the iceberg. https://t.co/yHPExuGXzx
# Longitude: None, Latitude: None
# Rajsthan Government shame on you..
# #IStandWithNupurSharma https://t.co/akKyQKZjkM
# Longitude: None, Latitude: None
# @adeyanjudeji #Adeyanju is a jack of all trades and master of none!
# Longitude: None, Latitude: None
# @MolotoMothapo So what your point here? Has he ever created a search engine or social media platform or fast-food outlet
# Longitude: None, Latitude: None
# @Hopton2470 @GlastoTopTips Reported
# Longitude: None, Latitude: None
# What is your purpose in blocking me on facebook? are u having a negative impact on me? we are not friends anyway 😅
# @ray_ban She sucks at drums .. anywho , hey Ray-Ban , partner with Twitter and I'll consider it .. Facebook no bueno
# Longitude: None, Latitude: None
# COVID-19 vaccine appointments for toddlers are available through Atlantic Health System, Zufall Health Center, and some local pharmacies. For more information, visit https://t.co/9GXC4s6cKX #RiverdaleNJ
# Longitude: None, Latitude: None
# At 48 secs  - live video bⓔhⓔading
#
# 2 Mμ$Ι¡mऽ  bⓔhⓔaded for H¡ηdu for  supporting Nupur Sharma
#
# Location : Udaipur, Rajasthan https://t.co/auX9a6eNIC
# Longitude: None, Latitude: None
# @ChetMonteiro @SaltyGary @MaryL1973 How do you know when somebody dies?
# Longitude: None, Latitude: None
# Very painful to see the disturbing videos and pics of the beheading of an innocent Tailor Kanhaiya Lal.
#
# These offenders must be Hanged @ashokgehlot51
#
# we can't even imagine the suffering and pain of Kanhaiya Lal's family.
#
# May God give them strength🙏
# Longitude: None, Latitude: None
# @DONATORSPH DONBELLE CLOSER MV
#
# #closeupxDonBelle
# #CloserWithDonBelle
# Longitude: None, Latitude: None
# @TajinderBagga @ashokgehlot51 @PTTVEnglish @ThanthiTV @polimernews @news7tamil @News18TamilNadu  You must have reported this by now. What's stopping you?
# Longitude: None, Latitude: None
# @VaughnK_ @Meredith5162 @DenisefromCali @AP @facebook @instagram We see you’ve been drinking too much Fox kool-aid 🤦‍♂️
# Longitude: None, Latitude: None
# No true Journalist will ever delete his old tweets or delete his Facebook account or format his phone unless he has an ulterior motive to deceive people &amp; spread hatred in soceity knowing fully well the grave consequences of his actions
#
# #IDontStandWithZubair https://t.co/hQuX6ndtnz
# Longitude: None, Latitude: None
# #Udaipur two jihadis lynched a hindu man (kanhaiya lal ji ) over his support to nupur sharma on a Facebook post.and they also intimidate pm modi that they will do the same#ashokgehlot
# #Nupur_Sharma #justice https://t.co/HvuMYdp5SS
# Longitude: None, Latitude: None
# @kinghills42 @Ekitipikin BOSS abeg help me fund my sporty acc
# Longitude: None, Latitude: None
# Meanwhile on Facebook, Madam Boss comforts her friend Deliwe https://t.co/gH4iWZ6LQr
# Longitude: None, Latitude: None
# @Meta deleting posts / ads for abortion pills. Instagram &amp; Facebook removing mentions of abortion pills and how to obtain them - from its platform. In what #Metaverse is this ok? https://t.co/iqkWknxJ0O
# Longitude: None, Latitude: None
# @PatrickMoorhead @amazon @awscloud @SixFivePodcast In the future every home and business in America will be connected by a rail to a network of elevated tracks for fully automated personal transportation and merchandise delivery using Alexa enabled autonomous electric vehicles: https://t.co/A0Q8ZvovTD
# Longitude: None, Latitude: None
# This my facebook registered https://t.co/Ffgl5OiJxv
# Longitude: None, Latitude: None
# @DDREAMERSOFC @donnypangilinan @bellemariano02 @CloseupPH DONBELLE CLOSER MV
#
# #closeupxDonBelle
# #CloserWithDonBelle https://t.co/W9rDmafmV5
# Longitude: None, Latitude: None
# GST Council accepts to adopt GoM recommendations for e-way Bill generation for gold, gold jewellery, and precious stones: Sources
# Link in bio for more details:
# .
# .
# .
# #taxyog
# #accountant #accounting #taxation
# Instagram:
# taxyog
#
# Facebook:
# Taxyog
#
# LinkedIn:
# Taxyog Social media dept https://t.co/0Z0pVQBdk8
# Longitude: None, Latitude: None
# This is on #zoobear &amp; the entire ecosystem that instigated the blasphemy issue #Rajasthan https://t.co/8pwjee64SO
# Longitude: None, Latitude: None
# The USA Women meet Spain today in quarterfinal action at #FINABudapest2022 today at 10am et/7am pt. The match is available on the @fina1908 Facebook page for $1.99.
# WATCH: https://t.co/3pbyFxu2II
# Longitude: None, Latitude: None
# @TajinderBagga @ashokgehlot51 Stop calling them patharbaj, they are b@h@ad@rs now.
# Longitude: None, Latitude: None
# Remember, you can also get our weekly briefing delivered straight to your email inbox by signing up at https://t.co/bY7O2YjMAx, and get all the latest updates on Facebook and Instagram @ seagullbtn!
# Longitude: None, Latitude: None
# Internet services in Udaipur, Rajasthan shut after brutal murder of a Hindu tailor by Islamists over taiilor's online status supporting suspended BJP spokesperson Nupur Sharma https://t.co/KcG30rsRYq
# Longitude: None, Latitude: None
# @DaveAtherton20 Sh/te
# Longitude: None, Latitude: None
# @flexghost1 Facebook is a Net Bad.
# Longitude: None, Latitude: None
# 📣YOU SOUND OFF:  What has your passport experience been like?
#
# 📞1-866-267-3797
# ✉️Feedback@BreakfastTelevision.ca 💬 LIVE on Facebook and YouTube!
# Or reply below!
# Longitude: None, Latitude: None
# Happy International PKU day 2022
#
# #PKU #RareDisease #BrainHealth #EmpoweringPKU #ESPKU #PKUDay2022 https://t.co/1zWF6Cij6S
# Longitude: None, Latitude: None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ac8edf15dc52> in <module>
#       8 myStream.add_rules(tweepy.StreamRule(f"{settings.TRACK_WORDS} lang:en -is:retweet"))
#       9 #Filtering the tweets using the rule added and using expansions to gather non-default tweet data
# ---> 10 myStream.filter(expansions=['author_id'],
#      11                 user_fields=['created_at','location','description','public_metrics'],
#      12                 tweet_fields=['created_at','geo','public_metrics'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, threaded, **params)
#     782             return self._threaded_connect(method, endpoint, params=params)
#     783         else:
# --> 784             self._connect(method, endpoint, params=params)
#     785
#     786     def get_rules(self, **params):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in _connect(self, method, endpoint, **kwargs)
#     602         self.session.headers["Authorization"] = f"Bearer {self.bearer_token}"
#     603         url = f"https://api.twitter.com/2/tweets/{endpoint}/stream"
# --> 604         super()._connect(method, url, **kwargs)
#     605
#     606     def _process_data(self, data, data_type=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in _connect(self, method, url, auth, params, headers, body)
#      85                                 break
#      86
# ---> 87                             for line in resp.iter_lines(
#      88                                 chunk_size=self.chunk_size
#      89                             ):
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     864         pending = None
#     865
# --> 866         for chunk in self.iter_content(
#     867             chunk_size=chunk_size, decode_unicode=decode_unicode
#     868         ):
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in generate()
#     814             if hasattr(self.raw, "stream"):
#     815                 try:
# --> 816                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     817                         yield chunk
#     818                 except ProtocolError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     570         """
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#     574         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     762
#     763             while True:
# --> 764                 self._update_chunk_length()
#     765                 if self.chunk_left == 0:
#     766                     break
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     692         if self.chunk_left is not None:
#     693             return
# --> 694         line = self._fp.fp.readline()
#     695         line = line.split(b";", 1)[0]
#     696         try:
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# C:\ProgramData\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# C:\ProgramData\Anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
